# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=[1,2,3,4]
y=[10,20,15,25]
plt.plot(x,y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Line plot Example")

plt.show()

# %%
ages=[20,22,25,30,35,40,22,25]
plt.hist(ages,bins=5)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
